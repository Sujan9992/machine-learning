# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('TopRichestInWorld.csv')
data
# Out:
#                          Name          NetWorth  Age Country/Territory  \
# 0                   Elon Musk  $219,000,000,000   50     United States
# 1                  Jeff Bezos  $171,000,000,000   58     United States
# 2    Bernard Arnault & family  $158,000,000,000   73            France
# 3                  Bill Gates  $129,000,000,000   66     United States
# 4              Warren Buffett  $118,000,000,000   91     United States
# ..                        ...               ...  ...               ...
# 96           Vladimir Potanin   $17,300,000,000   61            Russia
# 97       Harold Hamm & family   $17,200,000,000   76     United States
# 98               Sun Piaoyang   $17,100,000,000   63             China
# 99         Luo Liguo & family   $17,000,000,000   66             China
# 100                 Peter Woo   $17,000,000,000   75         Hong Kong
#
#                  Source               Industry
# 0         Tesla, SpaceX             Automotive
# ...

# %%
x = data.iloc[:]
x
# Out:
#                          Name          NetWorth  Age Country/Territory  \
# 0                   Elon Musk  $219,000,000,000   50     United States
# 1                  Jeff Bezos  $171,000,000,000   58     United States
# 2    Bernard Arnault & family  $158,000,000,000   73            France
# 3                  Bill Gates  $129,000,000,000   66     United States
# 4              Warren Buffett  $118,000,000,000   91     United States
# ..                        ...               ...  ...               ...
# 96           Vladimir Potanin   $17,300,000,000   61            Russia
# 97       Harold Hamm & family   $17,200,000,000   76     United States
# 98               Sun Piaoyang   $17,100,000,000   63             China
# 99         Luo Liguo & family   $17,000,000,000   66             China
# 100                 Peter Woo   $17,000,000,000   75         Hong Kong
#
#                  Source               Industry
# 0         Tesla, SpaceX             Automotive
# ...

# %%
y = data.iloc[:, 1]
y
# Out:
# 0      $219,000,000,000
# 1      $171,000,000,000
# 2      $158,000,000,000
# 3      $129,000,000,000
# 4      $118,000,000,000
#              ...
# 96      $17,300,000,000
# 97      $17,200,000,000
# 98      $17,100,000,000
# 99      $17,000,000,000
# 100     $17,000,000,000
# Name: NetWorth, Length: 101, dtype: object

# %%
x_train, x_text, y_train, y_test = train_test_split(x,y, test_size=30, random_state=1)

# %%
x_train
# Out:
#                           Name         NetWorth  Age Country/Territory  \
# 67                     Jack Ma  $22,800,000,000   57             China
# 73               Masayoshi Son  $21,300,000,000   64             Japan
# 19              Changpeng Zhao  $65,000,000,000   44            Canada
# 27              Dieter Schwarz  $47,100,000,000   82           Germany
# 48                He Xiangjian  $28,300,000,000   79             China
# ..                         ...              ...  ...               ...
# 75     Rupert Murdoch & family  $20,800,000,000   91     United States
# 9                Mukesh Ambani  $90,700,000,000   64             India
# 72  Thomas Frist, Jr. & family  $21,800,000,000   83     United States
# 12   Carlos Slim Helu & family  $81,200,000,000   82            Mexico
# 37          Stephen Schwarzman  $34,800,000,000   75     United States
#
#                      Source               Industry
# 67               e-commerce             Technology
# ...
