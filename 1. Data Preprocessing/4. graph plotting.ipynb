# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([0,10])
y = np.array([0,100])

# %%
x.shape
# Out:
# (2,)

# %%
y.shape
# Out:
# (2,)

# %%
plt.xlabel('Count')
plt.ylabel('Frequency')
plt.plot(x,y)

# %%
x1 = np.array([1,2,3,4,5])
y1 = np.array([2,5,6,3,7])
plt.plot(x1 ,y1, '+:', ms=10) # ms=min size, + marker, : dotted
